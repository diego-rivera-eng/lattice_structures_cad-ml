# %% [markdown]
# <a href="https://colab.research.google.com/github/diego-rivera-eng/lattice_structures_cad-ml/blob/main/01_lattice_modeling_section1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
